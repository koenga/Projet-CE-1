# %% [markdown]
# ### Imports

# %%
import pandas as pd
import pickle
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# Créer classe Barcelona
#
# Attribute = 3D tensor

# %% [markdown]
# ### Pickle files

# %%
with open(r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg\agg_timeseries_000.pkl", "rb") as f:
    data = pickle.load(f)

print(type(data))
print(data.keys())
# Out:
# <class 'collections.defaultdict'>
# dict_keys(['drone_vdist', 'drone_vtime', 'ld_speed', 'pred_vdist', 'pred_vtime'])

# %% [markdown]
# NaN -> 0

# %%
df_vdist = data['drone_vdist']
df_vtime = data['drone_vtime']
df_linkSpeed = data['ld_speed']
df_pred_vdist = data['pred_vdist']
df_pred_vtime = data['pred_vtime']
type(data['drone_vdist'])
# Out:
# pandas.core.frame.DataFrame

# %%
df_linkSpeed.shape
# Out:
# (54, 1570)

# %%
df_vdist.shape
# Out:
# (1917, 1570)

# %%
df_pred_vdist.shape
# Out:
# (54, 1570)

# %%
df_vdist.head()
# Out:
# section              512    513    514        516    593        594    595    \
# time
# 2005-05-10 07:45:05    NaN    NaN    NaN        NaN    NaN  57.925606    NaN
# 2005-05-10 07:45:10    NaN    NaN    NaN        NaN    NaN  72.781805    NaN
# 2005-05-10 07:45:15    NaN    NaN    NaN        NaN    NaN   2.868114    NaN
# 2005-05-10 07:45:20    NaN    NaN    NaN  26.619127    NaN  84.506888    NaN
# 2005-05-10 07:45:25    NaN    NaN    NaN  21.030500    NaN        NaN    NaN
#
# section              596    597    598    ...  64715  64751  64752  68076  \
# time                                      ...
# 2005-05-10 07:45:05    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN
# 2005-05-10 07:45:10    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN
# 2005-05-10 07:45:15    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN
# 2005-05-10 07:45:20    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN
# 2005-05-10 07:45:25    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN
#
# section              69616  69622  70330  72127  73054      73546
# time
# 2005-05-10 07:45:05    NaN    NaN    NaN    NaN    NaN        NaN
# 2005-05-10 07:45:10    NaN    NaN    NaN    NaN    NaN        NaN
# 2005-05-10 07:45:15    NaN    NaN    NaN    NaN    NaN  22.557620
# 2005-05-10 07:45:20    NaN    NaN    NaN    NaN    NaN  61.989363
# 2005-05-10 07:45:25    NaN    NaN    NaN    NaN    NaN  43.042688
#
# [5 rows x 1570 columns]

# %% [markdown]
# ### CSV files

# %%
df_pos = pd.read_csv(r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg\metadata\link_bboxes_clustered.csv")
df_pos.shape
# Out:
# (1570, 14)

# %%
# Tracer x en abscisse et y en ordonnée
plt.figure(figsize=(8, 6))  # Taille du graphique
plt.scatter(df_pos["c_x"], df_pos["c_y"], color="blue", alpha=0.5)  # Scatter plot

# Ajouter des titres et labels
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Links centroids")
plt.grid(True)

# Afficher le graphique
plt.show()
