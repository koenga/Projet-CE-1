# %%
# %run OurMain.py
# Out:
# Episode:  0
# Time | ep_step:  0 0
# 0.8894207800088825
# List move actions: [0, 1, 2, 3, 4]
# added an action: 0
# 0.31847975138299833
# List move actions: [0, 1, 2, 3, 4]
# added an action: 1
# 0.0
# List move actions: [0, 1, 2, 3, 4]
# 0.8972151235542914
# List move actions: [0, 1, 2, 3, 4]
# added an action: 3
# 0.8751373581663233
# List move actions: [0, 1, 2, 3, 4]
# added an action: 4
# Feasible actions: [0, 1, 3, 4]
# 0.0
# List move actions: [0, 1, 2, 3, 4]
# 0.829993133833448
# List move actions: [0, 1, 2, 3, 4]
# added an action: 1
# 0.9034797367509914
# List move actions: [0, 1, 2, 3, 4]
# added an action: 2
# 0.9426869799560197
# List move actions: [0, 1, 2, 3, 4]
# added an action: 3
# 0.44267073084659625
# List move actions: [0, 1, 2, 3, 4]
# added an action: 4
# Feasible actions: [1, 2, 3, 4]
# 0.8932491422667744
# List move actions: [0, 1, 2, 3, 4]
# added an action: 0
# 0.8166430531501271
# List move actions: [0, 1, 2, 3, 4]
# added an action: 1
# ...
