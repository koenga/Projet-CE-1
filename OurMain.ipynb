# %%
# %run OurMain.py
# Out:
# 54
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File D:\GitHub\Projet-CE-1\OurMain.py:113
#     109 #--------------------------------------------------------------------------------------------------------------------
#     111 F.update_drone_action_history(list_of_actions)
# --> 113 list_of_observations_, list_of_drone_positions_ = F.get_fleet_info(t_curr+1, T)
#     114 list_of_drone_states_ = F.get_drone_states(list_of_observations_, list_of_drone_positions_)
#     115 visit_matrix_ = F.visit_matrix
#
# File D:\GitHub\Projet-CE-1\Fleet.py:107, in Monitoring_Fleet.get_fleet_info(self, t, T)
#     104     d_x = drone.x
#     105     d_y = drone.y
# --> 107     d_observation = drone.get_observation(t, d_x, d_y, self.Map, self.visit_matrix, T, self.shared_info)
#     109     list_of_observations.append(d_observation)
# ...
