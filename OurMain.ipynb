# %%
# %run OurMain.py
# Out:
# Episode:  0
# Time | ep_step:  0 0
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# Went in the if in D.info_adjacent_nodes
# ...
