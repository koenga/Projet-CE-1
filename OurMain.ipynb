# %%
# %run OurMain.py
# Out:
# 54
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File D:\GitHub\Projet-CE-1\OurMain.py:137
#     134     list_of_drone_states    = list_of_drone_states_
#     136     t_curr  += 1
# --> 137     ep_step +=1
#     139 #----- Store transitions in the buffer -----
#     141 ep_curr += 1
#
# NameError: name 'ep_step' is not defined
