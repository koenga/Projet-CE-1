# %%
import Main

# %%
# %run Main.py
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File D:\GitHub\Projet-CE-1\Main.py:40
#      37 pretrained_folder = None
#      38 pretrained_folder = "/Results/11_20_2024_02_14_49_pretraining/Saved_models/policy_network_49999.pt"
# ---> 40 F = Monitoring_Fleet(Map, buffer_size, state_shape, pretrained_folder, True, num_stacked, alpha)
#      41 F.add_drones(drone_init_pos)
#      43 #----- Create save folder paths -----
#
# File D:\GitHub\Projet-CE-1\Fleet.py:66, in Monitoring_Fleet.__init__(self, Map, buffer_size, state_shape, pretrained_folder, lstm, num_stacked, alpha)
#      63 if pretrained_folder is not None:
#      65     load_weights = os.getcwd() + pretrained_folder
# ---> 66     self.policy_network.load_checkpoint(load_weights)
#      67     self.target_network.load_checkpoint(load_weights)
#      69 #----- Other params -----
#
# ...
