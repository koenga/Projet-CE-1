# %%
import Main

# %%
# %run Main.py
# Out:
# Episode:  0
# Time | ep_step:  0 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\GitHub\Projet-CE-1\Main.py:100
#      97     list_of_actions = F.move_drones_LSTM  (list_of_drone_states, list_of_observations, discount_param=0.1, recover_param=0.025)
#      99 else:
# --> 100     list_of_actions = F.move_drones_random(list_of_drone_states, list_of_observations, discount_param=0.1, recover_param=0.025)
#     102 #--------------------------------------------------------------------------------------------------------------------
#     104 F.update_drone_action_history(list_of_actions)
#
# File D:\GitHub\Projet-CE-1\Fleet.py:659, in Monitoring_Fleet.move_drones_random(self, list_of_drone_states, list_of_observations, discount_param, recover_param)
#     657     d_action      = drone.choose_action(d_observation, agent_type='random')
# ...
