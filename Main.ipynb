# %%
from RegionMap import RegionMap
import pandas as pd

# %%
x_size = 20
y_size = 30

list_of_small_pertb = [[0,4], [13,5], [17,25]]
list_of_big_pert = [[4,22],[13,15]]

Map = RegionMap(y_size, x_size, list_of_small_pertb, list_of_big_pert, timestep=None, df_link=None, link=None, listFileNumbers=None)
Map.initialize_importance_map()
Map.importance_map.shape
# Out:
# (20, 30)

# %%
link = r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg"
df_link = pd.read_csv(r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg\metadata\link_bboxes_clustered.csv")
listFileNumbers = ['000','001','002']
map = RegionMap(20, 15, [], [], 1, df_link = df_link, link = link, listFileNumbers=listFileNumbers)

# %%
map.gridTensor()
map.df_pos.head()
map.visualizeGrid()

# %%
id = 'ld_speed' 
df_id = map.getdf_id(id,"000")
df_id.head()
# Out:
# section                  512        513        514        516        593    \
# time
# 2005-05-10 07:48:00   0.000000   9.620164  11.425973   9.148113   0.000000
# 2005-05-10 07:51:00  11.418448  11.116159  10.848499   9.871054  11.340688
# 2005-05-10 07:54:00  10.204143  10.296071  11.105609   9.686721  11.141623
# 2005-05-10 07:57:00  10.855247  10.341236  10.927553  10.513366  10.735706
# 2005-05-10 08:00:00  11.042781  10.291154  10.850760   9.786850  10.788939
#
# section                  594    595        596        597       598    ...  \
# time                                                                   ...
# 2005-05-10 07:48:00  10.752834    0.0   0.000000   0.000000  0.000000  ...
# 2005-05-10 07:51:00  11.207304    0.0  11.204639  11.279689  9.961551  ...
# 2005-05-10 07:54:00  11.227360    0.0  11.195654  11.228628  9.778399  ...
# 2005-05-10 07:57:00  10.805220    0.0  10.784818  10.788266  9.578361  ...
# ...

# %%
timestep = df_id.index.astype(str).tolist()[0]
tensor = map.createMatrix(timestep, id)

# %%
y = map.y_size
x = map.x_size
print(x,y)
# Out:
# 15 20

# %%
tensor.shape
# Out:
# (20, 15)

# %%
id = 'ld_speed'
id0 = map.getdf_id(id, '000')
timestep = id0.index.astype(str).tolist()[0]
M0 = map.createMatrix(timestep, id)
print(M0[14,3])
# Out:
# 6.147744990039094

# %%
id = 'pred_vdist'
id1 = map.getdf_id(id, '000')
timestep = id1.index.astype(str).tolist()[0]
M1 = map.createMatrix(timestep, id)
print(M1[14,3])
# Out:
# 5.11490623901908

# %%
id = 'pred_vtime'
id2 = map.getdf_id(id, '000')
timestep = id2.index.astype(str).tolist()[0]
M2 = map.createMatrix(timestep, id)
print(M2[14,3])
# Out:
# 0.48045526316837134

# %%
link = r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg"
df_link = pd.read_csv(r"D:\EPFL\MA2\Projet\Code\Data\datasets\simbarca\all_agg\metadata\link_bboxes_clustered.csv")
listFileNumbers = ['000']
map = RegionMap(20, 15, [], [], 1, df_link = df_link, link = link, listFileNumbers=listFileNumbers)

id = 'ld_speed'
map.initialize_better_importance_map(id)
tensor3D = map.importance_map

# %%
id = 'pred_vdist'
map.initialize_better_importance_map(id)
tensor_vdist = map.importance_map

# %%
id = 'pred_vtime'
map.initialize_better_importance_map(id)
tensor_vtime = map.importance_map

# %%
tensor_vdist[0,15,3]
# Out:
# np.float64(23.928790155082563)

# %%
tensor_vtime[0,15,3]
# Out:
# np.float64(4.916461973732427)

# %%
tensor3D[0,15,3]
# Out:
# np.float64(10.381568626437907)

# %%
tensor3D.shape
# Out:
# (70, 20, 15)

# %%
map.visualize_grid_with_heatmap(tensor_vtime, 3)

# %%
map.visualize_grid_with_heatmap(tensor_vdist, 3)

# %%
map.visualize_grid_with_heatmap(tensor3D, 3)

# %%
df_pos = map.df_pos
df_pos.head()
# Out:
#     id            c_x           c_y grid_cell
# 0  512  429919.864530  4.583030e+06    (3, 6)
# 1  513  429910.282390  4.583025e+06    (3, 6)
# 2  514  429908.548351  4.583006e+06    (4, 6)
# 3  516  432567.505979  4.582818e+06   (5, 13)
# 4  593  432699.655713  4.581715e+06  (11, 14)

# %% [markdown]
# T := total number of steps for the simulation.

# %%
# %run Main.py
# Out:
# Episode:  0
# Time | ep_step:  0 0
# Time | ep_step:  1 1
# Time | ep_step:  2 2
# Time | ep_step:  3 3
# Time | ep_step:  4 4
# -----------
# Episode:  1
# Time | ep_step:  5 0
# Time | ep_step:  6 1
# Time | ep_step:  7 2
# Time | ep_step:  8 3
# Time | ep_step:  9 4
# -----------
# Episode:  2
# Time | ep_step:  10 0
# Time | ep_step:  11 1
# Time | ep_step:  12 2
# Time | ep_step:  13 3
# Time | ep_step:  14 4
# -----------
# Episode:  3
# Time | ep_step:  15 0
# Time | ep_step:  16 1
# Time | ep_step:  17 2
# Time | ep_step:  18 3
# Time | ep_step:  19 4
# -----------
# Episode:  4
# Time | ep_step:  20 0
# Time | ep_step:  21 1
# Time | ep_step:  22 2
# Time | ep_step:  23 3
# Time | ep_step:  24 4
# -----------
# Episode:  5
# Time | ep_step:  25 0
# Time | ep_step:  26 1
# Time | ep_step:  27 2
# Time | ep_step:  28 3
# Time | ep_step:  29 4
# -----------
# Episode:  6
# Time | ep_step:  30 0
# Time | ep_step:  31 1
# Time | ep_step:  32 2
# Time | ep_step:  33 3
# ...

# %%
# %run Main_pretrain.py
# Out:
# Iteration: 199
# Loss:  11.318588
# Iteration: 399
# Loss:  9.356397
# Iteration: 599
# Loss:  9.804739
# Iteration: 799
# Loss:  8.93831
# D:\GitHub\Projet-CE-1\Fleet.py:583: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# Iteration: 999
# Loss:  10.709579
# Iteration: 1199
# Loss:  8.075152
# Iteration: 1399
# Loss:  11.9761
# Iteration: 1599
# Loss:  14.002395
# Iteration: 1799
# Loss:  8.861947
# D:\GitHub\Projet-CE-1\Fleet.py:583: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# Iteration: 1999
# Loss:  9.960837
# Iteration: 2199
# Loss:  11.78673

# %% [markdown]
# LSTM := Long Short Term Memory

# %%
# %run Main_gather_pretrain_data_LSTM
